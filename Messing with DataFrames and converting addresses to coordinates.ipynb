# %%
import pandas as pd

# %%
import os
os.listdir()
# Out:
# ['The GroupBy Project.ipynb',
#  'nba.csv',
#  'fortune1000.csv',
#  'Restaurant - Week 2 Sales.csv',
#  'Data - Single Worksheet.xlsx',
#  'Working with Dates and Times in Datasets.ipynb',
#  'NYC_Baby_Names.csv',
#  'Series.ipynb.webloc',
#  'Untitled.ipynb',
#  'Baby_Names.xlsx',
#  'Visualization.ipynb',
#  'revenue.csv',
#  'Restaurant - Customers.csv',
#  'supermarkets.json',
#  'jamesbond.csv',
#  'worldstats.csv',
#  'supermarkets.csv',
#  'supermarkets-semi-colons.txt',
#  'chicago.csv',
#  'pokemon.csv',
#  'Dataframes 2.ipynb',
#  'quarters.csv',
#  'supermarkets.xlsx',
#  'salesmen.csv',
#  'Options and Settings.ipynb',
#  'Restaurant - Foods.csv',
#  'Input and Output in pandas.ipynb',
#  'foods.csv',
#  'MultiIndex.ipynb',
#  '.ipynb_checkpoints',
#  'bigmac.csv',
#  'Python Crash Course.ipynb',
#  'Dataframes 3.ipynb',
#  'Read csv series.ipynb',
#  'employees.csv',
#  'Working With Text Data.ipynb',
#  'google_stock_price.csv',
#  'Dataframes 1.ipynb',
#  'Restaurant - Week 1 Satisfaction.csv',
#  'ecommerce.csv',
#  'Test.ipynb',
#  'supermarkets-commas.txt',
#  'Merging, Joining, and Concatenating DataFrames.ipynb',
#  'Restaurant - Week 1 Sales.csv',
#  'Data - Multiple Worksheets.xlsx']

# %%
df1 = pd.read_csv("supermarkets.csv")

# %%
df1.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df2 = pd.read_json("supermarkets.json")
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /opt/anaconda3/envs/pandas_playground/lib/python3.9/site-packages (3.0.7)
# Requirement already satisfied: et-xmlfile in /opt/anaconda3/envs/pandas_playground/lib/python3.9/site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xlrd
# Out:
# Requirement already satisfied: xlrd in /opt/anaconda3/envs/pandas_playground/lib/python3.9/site-packages (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
df3 = pd.read_excel("supermarkets.xlsx", sheet_name = 0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4 = pd.read_csv("supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pd.read_csv("supermarkets-semi-colons.txt", sep=";")
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6 = pd.read_json("http://pythonhow.com/supermarkets.json")
df6
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6 = pd.read_csv("supermarkets.csv")
df6
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6.columns = ["ID", "Address", "City", "ZIP", "Country", "Name", "Employee"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-f9b6504f8648> in <module>
# ----> 1 df6.columns = ["ID", "Address", "City", "ZIP", "Country", "Name", "Employee"]
#
# /opt/anaconda3/envs/pandas_playground/lib/python3.9/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5489         try:
#    5490             object.__getattribute__(self, name)
# -> 5491             return object.__setattr__(self, name, value)
#    5492         except AttributeError:
#    5493             pass
#
# /opt/anaconda3/envs/pandas_playground/lib/python3.9/site-packages/pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /opt/anaconda3/envs/pandas_playground/lib/python3.9/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     761     def _set_axis(self, axis: int, labels: Index) -> None:
#     762         labels = ensure_index(labels)
# --> 763         self._mgr.set_axis(axis, labels)
#     764         self._clear_item_cache()
#     765
#
# /opt/anaconda3/envs/pandas_playground/lib/python3.9/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     214     def set_axis(self, axis: int, new_labels: Index) -> None:
#     215         # Caller is responsible for ensuring we have an Index object.
# --> 216         self._validate_set_axis(axis, new_labels)
#     217         self.axes[axis] = new_labels
#     218
#
# /opt/anaconda3/envs/pandas_playground/lib/python3.9/site-packages/pandas/core/internals/base.py in _validate_set_axis(self, axis, new_labels)
#      55
#      56         elif new_len != old_len:
# ---> 57             raise ValueError(
#      58                 f"Length mismatch: Expected axis has {old_len} elements, new "
#      59                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 6 elements, new values have 7 elements

# %%
df6
# Out:
#    ID          Address           City               ZIP  Country         Name  \
# 0  ID          Address           City             State  Country         Name
# 1   1     3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2   2   735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3   3      332 Hill St  San Francisco  California 94114      USA  Super River
# 4   4     3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   5  1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#     Employee
# 0  Employees
# 1          8
# 2         15
# 3         25
# 4         10
# 5         12
# 6         20

# %%
df6.set_index("ID")
# Out:
#             Address           City               ZIP  Country         Name  \
# ID
# ID          Address           City             State  Country         Name
# 1      3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114      USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#      Employee
# ID
# ID  Employees
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df7 = df6.set_index("ID")

# %%
df7.set_index("Address")
# Out:
#                           City               ZIP  Country         Name  \
# Address
# Address                   City             State  Country         Name
# 3666 21st St     San Francisco          CA 94114      USA      Madeira
# 735 Dolores St   San Francisco          CA 94119      USA  Bready Shop
# 332 Hill St      San Francisco  California 94114      USA  Super River
# 3995 23rd St     San Francisco          CA 94114      USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California      USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#                   Employee
# Address
# Address          Employees
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df7.set_index("Name", inplace = True, drop = False)

# %%
df7
# Out:
#             Address           City               ZIP  Country         Name  \
# ID
# ID          Address           City             State  Country         Name
# 1      3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114      USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#      Employee
# ID
# ID  Employees
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df7.set_index("Address")
# Out:
#                           City               ZIP  Country         Name  \
# Address
# Address                   City             State  Country         Name
# 3666 21st St     San Francisco          CA 94114      USA      Madeira
# 735 Dolores St   San Francisco          CA 94119      USA  Bready Shop
# 332 Hill St      San Francisco  California 94114      USA  Super River
# 3995 23rd St     San Francisco          CA 94114      USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California      USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#                   Employee
# Address
# Address          Employees
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df6=df6.set_index("Address")
df6.loc["332 Hill St", "Country"]
# Out:
# 'USA'

# %%
list(df7.loc[:,"Country"])
# Out:
# ['Country', 'USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df7
# Out:
#             Address           City               ZIP  Country         Name  \
# ID
# ID          Address           City             State  Country         Name
# 1      3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114      USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#      Employee
# ID
# ID  Employees
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df4.iloc[1:3,1:3]
# Out:
#           Address           City
# 1  735 Dolores St  San Francisco
# 2     332 Hill St  San Francisco

# %%
df7.drop("City", 1)
# Out:
# <ipython-input-110-4701bbf5d55f>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df7.drop("City", 1)
#             Address               ZIP  Country         Name   Employee
# ID
# ID          Address             State  Country         Name  Employees
# 1      3666 21st St          CA 94114      USA      Madeira          8
# 2    735 Dolores St          CA 94119      USA  Bready Shop         15
# 3       332 Hill St  California 94114      USA  Super River         25
# 4      3995 23rd St          CA 94114      USA   Ben's Shop         10
# 5   1056 Sanchez St        California      USA      Sanchez         12
# 6   551 Alvarado St          CA 94114      USA   Richvalley         20

# %%
df6.drop("332 Hill St", 0)
# Out:
# <ipython-input-115-42268a1af87e>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df6.drop("332 Hill St", 0)
#                  ID           City       State Country         Name  Employees
# Address
# 3666 21st St      1  San Francisco    CA 94114     USA      Madeira          8
# 735 Dolores St    2  San Francisco    CA 94119     USA  Bready Shop         15
# 3995 23rd St      4  San Francisco    CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St   5  San Francisco  California     USA      Sanchez         12
# 551 Alvarado St   6  San Francisco    CA 94114     USA   Richvalley         20

# %%
df7.drop(df7.columns[0:3],1)
# Out:
# <ipython-input-117-01ad3c5cb97a>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df7.drop(df7.columns[0:3],1)
#     Country         Name   Employee
# ID
# ID  Country         Name  Employees
# 1       USA      Madeira          8
# 2       USA  Bready Shop         15
# 3       USA  Super River         25
# 4       USA   Ben's Shop         10
# 5       USA      Sanchez         12
# 6       USA   Richvalley         20

# %%
df7.drop(df7.index[0:3],0)
# Out:
# <ipython-input-118-cafb3db5166a>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df7.drop(df7.index[0:3],0)
#             Address           City               ZIP Country         Name  \
# ID
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employee
# ID
# 3        25
# 4        10
# 5        12
# 6        20

# %%
df7
# Out:
#             Address           City               ZIP  Country         Name  \
# ID
# ID          Address           City             State  Country         Name
# 1      3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114      USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#      Employee
# ID
# ID  Employees
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df7.set_index("Address")
# Out:
#                           City               ZIP  Country         Name  \
# Address
# Address                   City             State  Country         Name
# 3666 21st St     San Francisco          CA 94114      USA      Madeira
# 735 Dolores St   San Francisco          CA 94119      USA  Bready Shop
# 332 Hill St      San Francisco  California 94114      USA  Super River
# 3995 23rd St     San Francisco          CA 94114      USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California      USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#                   Employee
# Address
# Address          Employees
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df7["Continent"] = df7.shape[0]*["North America"]

# %%
df7
# Out:
#             Address           City               ZIP  Country         Name  \
# ID
# ID          Address           City             State  Country         Name
# 1      3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114      USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#      Employee      Continent
# ID
# ID  Employees  North America
# 1           8  North America
# 2          15  North America
# 3          25  North America
# 4          10  North America
# 5          12  North America
# 6          20  North America

# %%
df7.shape
# Out:
# (7, 7)

# %%
df7["Continent"] = df7["Country"]+ "," + "North America"

# %%
df7
# Out:
#             Address           City               ZIP  Country         Name  \
# ID
# ID          Address           City             State  Country         Name
# 1      3666 21st St  San Francisco          CA 94114      USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119      USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114      USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114      USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California      USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114      USA   Richvalley
#
#      Employee              Continent
# ID
# ID  Employees  Country,North America
# 1           8      USA,North America
# 2          15      USA,North America
# 3          25      USA,North America
# 4          10      USA,North America
# 5          12      USA,North America
# 6          20      USA,North America

# %%
df7_t = df7.T

# %%
df7_t
# Out:
# ID                            ID                  1                  2  \
# Address                  Address       3666 21st St     735 Dolores St
# City                        City      San Francisco      San Francisco
# ZIP                        State           CA 94114           CA 94119
# Country                  Country                USA                USA
# Name                        Name            Madeira        Bready Shop
# Employee               Employees                  8                 15
# Continent  Country,North America  USA,North America  USA,North America
#
# ID                         3                  4                  5  \
# Address          332 Hill St       3995 23rd St    1056 Sanchez St
# City           San Francisco      San Francisco      San Francisco
# ZIP         California 94114           CA 94114         California
# Country                  USA                USA                USA
# Name             Super River         Ben's Shop            Sanchez
# Employee                  25                 10                 12
# Continent  USA,North America  USA,North America  USA,North America
#
# ID                         6
# Address      551 Alvarado St
# City           San Francisco
# ZIP                 CA 94114
# Country                  USA
# Name              Richvalley
# Employee                  20
# Continent  USA,North America

# %%
df7_t["My Address"] = ["My City", "My Country", 10, 7, "My Shop", "My State", "My Continent"]

# %%
df7_t
# Out:
# ID                            ID                  1                  2  \
# Address                  Address       3666 21st St     735 Dolores St
# City                        City      San Francisco      San Francisco
# ZIP                        State           CA 94114           CA 94119
# Country                  Country                USA                USA
# Name                        Name            Madeira        Bready Shop
# Employee               Employees                  8                 15
# Continent  Country,North America  USA,North America  USA,North America
#
# ID                         3                  4                  5  \
# Address          332 Hill St       3995 23rd St    1056 Sanchez St
# City           San Francisco      San Francisco      San Francisco
# ZIP         California 94114           CA 94114         California
# Country                  USA                USA                USA
# Name             Super River         Ben's Shop            Sanchez
# Employee                  25                 10                 12
# Continent  USA,North America  USA,North America  USA,North America
#
# ID                         6    My Address
# Address      551 Alvarado St       My City
# City           San Francisco    My Country
# ZIP                 CA 94114            10
# Country                  USA             7
# Name              Richvalley       My Shop
# Employee                  20      My State
# Continent  USA,North America  My Continent

# %%
df7=df7_t.T

# %%
df7
# Out:
#                     Address           City               ZIP  Country  \
# ID
# ID                  Address           City             State  Country
# 1              3666 21st St  San Francisco          CA 94114      USA
# 2            735 Dolores St  San Francisco          CA 94119      USA
# 3               332 Hill St  San Francisco  California 94114      USA
# 4              3995 23rd St  San Francisco          CA 94114      USA
# 5           1056 Sanchez St  San Francisco        California      USA
# 6           551 Alvarado St  San Francisco          CA 94114      USA
# My Address          My City     My Country                10        7
#
#                    Name   Employee              Continent
# ID
# ID                 Name  Employees  Country,North America
# 1               Madeira          8      USA,North America
# 2           Bready Shop         15      USA,North America
# 3           Super River         25      USA,North America
# 4            Ben's Shop         10      USA,North America
# 5               Sanchez         12      USA,North America
# 6            Richvalley         20      USA,North America
# My Address      My Shop   My State           My Continent

# %%
pip install geopy
# Out:
# Collecting geopy
#   Downloading geopy-2.2.0-py3-none-any.whl (118 kB)
#      |████████████████████████████████| 118 kB 4.9 MB/s eta 0:00:01
# Collecting geographiclib<2,>=1.49
#   Downloading geographiclib-1.52-py3-none-any.whl (38 kB)
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.52 geopy-2.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from geopy.geocoders import ArcGIS

# %%
nom = ArcGIS()

# %%
n = nom.geocode("3995 23rd St, San Francisco, CA 94114")

# %%
n.latitude
# Out:
# 37.75292099814533

# %%
n.longitude
# Out:
# -122.43170295955227

# %%
type(n)
# Out:
# geopy.location.Location

# %%
df = pd.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df["Address"] = df["Address"]+ "," + df["City"]+ "," +["State"]+ "," +["Country"]
df
# Out:
#    ID                                      Address           City  \
# 0   1     3666 21st St,San Francisco,State,Country  San Francisco
# 1   2   735 Dolores St,San Francisco,State,Country  San Francisco
# 2   3      332 Hill St,San Francisco,State,Country  San Francisco
# 3   4     3995 23rd St,San Francisco,State,Country  San Francisco
# 4   5  1056 Sanchez St,San Francisco,State,Country  San Francisco
# 5   6  551 Alvarado St,San Francisco,State,Country  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df["Coordinates"] = df["Address"].apply(nom.geocode)

# %%
df.Coordinates
# Out:
# 0    (3666 21st St, San Francisco, California, 9411...
# 1    (735 Dolores St, San Francisco, California, 94...
# 2    (332 Hill St, San Francisco, California, 94114...
# 3    (3995 23rd St, San Francisco, California, 9411...
# 4    (1056 Sanchez St, San Francisco, California, 9...
# 5    (551 Alvarado St, San Francisco, California, 9...
# Name: Coordinates, dtype: object

# %%
df.Coordinates[0]
# Out:
# Location(3666 21st St, San Francisco, California, 94114, (37.756632001957215, -122.42941101194798, 0.0))

# %%
df["Latitude"] = df["Coordinates"].apply(lambda x: x.latitude)
df["Longitude"] = df["Coordinates"].apply(lambda x: x.longitude)


df
# Out:
#    ID                                      Address           City  \
# 0   1     3666 21st St,San Francisco,State,Country  San Francisco
# 1   2   735 Dolores St,San Francisco,State,Country  San Francisco
# 2   3      332 Hill St,San Francisco,State,Country  San Francisco
# 3   4     3995 23rd St,San Francisco,State,Country  San Francisco
# 4   5  1056 Sanchez St,San Francisco,State,Country  San Francisco
# 5   6  551 Alvarado St,San Francisco,State,Country  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# 0  (3666 21st St, San Francisco, California, 9411...  37.756632 -122.429411
# 1  (735 Dolores St, San Francisco, California, 94...  37.757829 -122.425373
# 2  (332 Hill St, San Francisco, California, 94114...  37.755845 -122.428813
# 3  (3995 23rd St, San Francisco, California, 9411...  37.752921 -122.431703
# 4  (1056 Sanchez St, San Francisco, California, 9...  37.752132 -122.430006
# 5  (551 Alvarado St, San Francisco, California, 9...  37.753582 -122.433234
